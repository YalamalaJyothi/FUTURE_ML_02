# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
data = {
    'Ticket': [
        'Payment failed during transaction',
        'Unable to login to account',
        'App is running very slow',
        'Need help changing password',
        'Internet connection issue',
        'Refund not received',
        'Website is crashing',
        'Forgot my password',
        'Billing problem in my account',
        'Technical issue with app'
    ],

    'Category': [
        'Payment',
        'Account',
        'Technical',
        'Account',
        'Technical',
        'Payment',
        'Technical',
        'Account',
        'Payment',
        'Technical'
    ]
}
df = pd.DataFrame(data)
X = df['Ticket']
y = df['Category']
vectorizer = CountVectorizer()
X_vectorized = vectorizer.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
    X_vectorized, y, test_size=0.2, random_state=42)
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy:", accuracy)

# Test with new ticket
new_ticket = ["My payment is not working"]
new_ticket_vector = vectorizer.transform(new_ticket)
prediction = model.predict(new_ticket_vector)
print("Predicted Category:", prediction[0])
# Out:
# Model Accuracy: 0.5
# Predicted Category: Payment
